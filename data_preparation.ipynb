# %% [markdown]
# <a href="https://colab.research.google.com/github/Laurasgrv-colab/Case-Heat-pump-modeling-tool/blob/main/data_preparation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

source_df = pd.read_excel("data/HP_case_data.xlsx", sheet_name="Heat source")
sink_df = pd.read_excel("data/HP_case_data.xlsx", sheet_name="Heat sink")

# Clean up column names
source_df.columns = source_df.columns.str.strip()
sink_df.columns = sink_df.columns.str.strip()

# Convert time columns to actual Datetime format 
source_df['start measurement'] = pd.to_datetime(source_df['start measurement'])
sink_df['start measurement'] = pd.to_datetime(sink_df['start measurement'])

# Merge the dataframes on the start measurement timestamp
merged_df = pd.merge(source_df, sink_df, on='start measurement', suffixes=('_source', '_sink'))

# Select and rename the columns we need for our TESPy model
cleaned_df = merged_df[[
    'start measurement',
    'T_in[degC_source',  # Heat source temperature coming in
    'flow[kg/s]',         # Heat source mass flow rate
    'T_in[degC_sink',    # Heat sink return temperature
    'T_out[degC]_sink',        # Heat sink delivery temperature (90°C)
    'T_out[degC]_source',
    'Energy[kWh]'         # The thermal load we need to deliver
]].copy()

# Rename columns for comfort
cleaned_df.columns = ['timestamp', 'T_source_in', 'flow_source', 'T_sink_in', 'T_sink_out', 'T_source_out6', 'heat_load_kW']

# Display the first few rows to confirm it looks correct
print(cleaned_df.head())
# Out:
#                 timestamp  T_source_in  flow_source  T_sink_in  T_sink_out  \
# 0 2024-01-01 00:00:00.000    56.303558            2         60          90
# 1 2024-01-01 01:00:00.000    56.272730            2         60          90
# 2 2024-01-01 01:59:59.990    56.409649            2         60          90
# 3 2024-01-01 02:59:59.985    56.926243            2         60          90
# 4 2024-01-01 03:59:59.980    57.631278            2         60          90
#
#    T_source_out  heat_load_kW
# 0            20    999.491087
# 1            20    997.054953
# 2            20   1003.651237
# 3            20   1009.563472
# 4            20   1011.220805
# c:\Users\laura\AppData\Local\Programs\Python\Python312\Lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Sparkline Group extension is not supported and will be removed
#   warn(msg)

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# Out:
#            start measurement  end measurement_source  T_in[degC_source  \
# 0    2024-01-01 00:00:00.000 2024-01-01 01:00:00.000         56.303558
# 1    2024-01-01 01:00:00.000 2024-01-01 01:59:59.990         56.272730
# 2    2024-01-01 01:59:59.990 2024-01-01 02:59:59.975         56.409649
# 3    2024-01-01 02:59:59.985 2024-01-01 03:59:59.965         56.926243
# 4    2024-01-01 03:59:59.980 2024-01-01 04:59:59.955         57.631278
# ...                      ...                     ...               ...
# 8779 2024-12-31 18:59:16.105 2024-12-31 19:58:32.205         55.025262
# 8780 2024-12-31 19:59:16.100 2024-12-31 20:58:32.195         54.957070
# 8781 2024-12-31 20:59:16.095 2024-12-31 21:58:32.185         54.888878
# 8782 2024-12-31 21:59:16.090 2024-12-31 22:58:32.175         54.820687
# 8783 2024-12-31 22:59:16.085 2024-12-31 23:58:32.165         54.820687
#
#       T_out[degC]_source  P[bar]_source  flow[kg/s]  Fluid  \
# 0                     20              2           2  water
# 1                     20              2           2    NaN
# 2                     20              2           2    NaN
# 3                     20              2           2    NaN
# 4                     20              2           2    NaN
# ...                  ...            ...         ...    ...
# 8779                  20              2           2    NaN
# 8780                  20              2           2    NaN
# 8781                  20              2           2    NaN
# 8782                  20              2           2    NaN
# 8783                  20              2           2    NaN
#
#         end measurement_sink  T_in[degC_sink  T_out[degC]_sink  P[bar]_sink  \
# 0    2024-01-01 01:00:00.000              60                90            2
# 1    2024-01-01 01:59:59.990              60                90            2
# 2    2024-01-01 02:59:59.975              60                90            2
# 3    2024-01-01 03:59:59.965              60                90            2
# 4    2024-01-01 04:59:59.955              60                90            2
# ...                      ...             ...               ...          ...
# 8779 2024-12-31 19:58:32.205              60                90            2
# 8780 2024-12-31 20:58:32.195              60                90            2
# 8781 2024-12-31 21:58:32.185              60                90            2
# 8782 2024-12-31 22:58:32.175              60                90            2
# 8783 2024-12-31 23:58:32.165              60                90            2
#
#       Energy[kWh]  Unnamed: 6  fluid
# 0      999.491087         NaN  water
# 1      997.054953         NaN    NaN
# 2     1003.651237         NaN    NaN
# 3     1009.563472         NaN    NaN
# 4     1011.220805         NaN    NaN
# ...           ...         ...    ...
# 8779  1051.578220         NaN    NaN
# 8780  1052.112335         NaN    NaN
# 8781  1052.646450         NaN    NaN
# 8782  1053.180564         NaN    NaN
# 8783  1053.180564         NaN    NaN
#
# [8784 rows x 14 columns]
